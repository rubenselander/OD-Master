# %%
import json
import cohere
from deeplake.core.vectorstore.deeplake_vectorstore import VectorStore
import json
import os

# load the local .env file
from dotenv import load_dotenv

load_dotenv()

co = cohere.Client(os.environ["COHERE_API_KEY"])
VECTOR_STORE_NAME = "eurostat"  # Name of vector store on activeloop hub

vector_store = VectorStore(path=VECTOR_STORE_NAME)


# # Potential filter function for vector_store.search
# Out:
# Deep Lake Dataset in eurostat already exists, loading from the storage

# %%
def cohere_embedding_function(texts, model="embed-multilingual-v3.0"):
    if isinstance(texts, str):
        texts = [texts]

    response = co.embed(texts, model=model, input_type="search_query")
    return response.embeddings


def search_tables(search_string: str, k: int = 10):
    """Performs a search in tables based on the given search string."""
    results = vector_store.search(
        embedding_data=search_string,
        embedding_function=cohere_embedding_function,
        # exec_option="tensor_db",
        return_tensors=["text", "code", "start_date", "end_date", "variables"],
        k=k,
    )
    return results


def format_search_results(search_results: dict, include_score: bool = False) -> dict:
    """Formats the search results to the format expected by the frontend."""
    if not include_score:
        search_results.pop("score", None)
    formatted_results = []
    # number of results is equal to the length of any of the lists in the dict
    # set the number of results to the length of the FIRST list in the dict
    nbr_of_results = len(list(search_results.values())[0])
    # each dict in the formatted_results list should have all the same keys
    # as the search_results dict

    for i in range(nbr_of_results):
        result = {}
        for key, value in search_results.items():
            if isinstance(value[i], list) and len(value[i]) == 1:
                result[key] = value[i][0]
            else:
                result[key] = value[i]
        formatted_results.append(result)

    return formatted_results


def search_eurostat(search_string: str, year: int = None, k=10) -> dict:
    """Performs a search in Eurostat based on the given search string."""
    search_results = search_tables(search_string, k=k)
    # possible reranking is done here
    # RERANK
    formatted_results = format_search_results(search_results)
    return formatted_results


def od_search(search_string: str, k: int = 10):
    """Performs a search in tables based on the given search string."""

    results = search_eurostat(search_string, k=k)
    base_url = "https://ec.europa.eu/eurostat/databrowser/view/{CODE}/default/table"
    results_with_urls = []
    for res in results:
        url = base_url.format(CODE=res["code"].lower())
        res.pop("code", None)
        res["url"] = url
        results_with_urls.append(res)
    return results_with_urls


# term = "interest rates"
# k = 10


# results = od_search(search_string=term)

# loaded_results = []
# for res in results:
#     print(res)

# %%
term = "interest rates"
search_terms = [
    "interest rates",
    "unemployment",
    "inflation",
    "gdp",
    "number of companies",
    "konkurs",
    "employment",
    "unemployment",
    "bankruptcies",
]


all_results = []
save_path = "search_results.txt"
k = 25


found_titles = set()

for search_term in search_terms:
    print(f"Searching for {search_term}")
    results = od_search(search_string=search_term, k=k)
    for res in results:
        if res["text"] not in found_titles:
            all_results.append(res)
            found_titles.add(res["text"])
        else:
            pass

with open(save_path, "w", encoding="utf-8") as f:
    # one item per line
    for item in all_results:
        f.write(item + "\n")
# Out:
# {'text': 'Money market interest rates', 'start_date': array([2022], dtype=int64), 'end_date': array([2005], dtype=int64), 'variables': {'freq': {'text': 'Time frequency', 'values': {'A': 'Annual'}}, 'int_rt': {'text': 'Interest rate', 'values': {'IRT_DTD': 'Day-to-day rate', 'IRT_M12': '12-month rate'}}, 'geo': {'text': 'Geopolitical entity (reporting)', 'values': {'MD': 'Moldova', 'UA': 'Ukraine', 'GE': 'Georgia', 'BY': 'Belarus', 'AM': 'Armenia', 'AZ': 'Azerbaijan'}}, 'time': {'text': 'Time', 'values': {}}}, 'url': 'https://ec.europa.eu/eurostat/databrowser/view/enpe_irt_st/default/table'}
# {'text': 'Interest rates - monthly data', 'start_date': array([2023], dtype=int64), 'end_date': array([1980], dtype=int64), 'variables': {'freq': {'text': 'Time frequency', 'values': {'M': 'Monthly'}}, 's_adj': {'text': 'Seasonal adjustment', 'values': {'NSA': 'Unadjusted data (i.e. neither seasonally adjusted nor calendar adjusted data)'}}, 'p_adj': {'text': 'Price adjustment', 'values': {'NAP': 'Not applicable'}}, 'indic': {'text': 'Indicator', 'values': {'MF-DDI-RT': 'Day-to-day money market interest rates (average)', 'MF-3MI-RT': '3-month interest rates (average)', 'MF-EY1YM-RT': 'Euro yields - 1 year (average)', 'MF-EY5YM-RT': 'Euro yields - 5 years (average)', 'MF-EY10YM-RT': 'Euro yields - 10 years (average)', 'MF-LTGBY-RT': 'Long term government bond yields - Maastricht definition (average)'}}, 'geo': {'text': 'Geopolitical entity (reporting)', 'values': {'EU27_2020': 'European Union - 27 countries (from 2020)', 'EU28': 'European Union - 28 countries (2013-2020)', 'EA': 'Euro area (EA11-1999, EA12-2001, EA13-2007, EA15-2008, EA16-2009, EA17-2011, EA18-2014, EA19-2015, EA20-2023)', 'BE': 'Belgium', 'BG': 'Bulgaria', 'CZ': 'Czechia', 'DK': 'Denmark', 'DE': 'Germany', 'EE': 'Estonia', 'IE': 'Ireland', 'EL': 'Greece', 'ES': 'Spain', 'FR': 'France', 'HR': 'Croatia', 'IT': 'Italy', 'CY': 'Cyprus', 'LV': 'Latvia', 'LT': 'Lithuania', 'LU': 'Luxembourg', 'HU': 'Hungary', 'MT': 'Malta', 'NL': 'Netherlands', 'AT': 'Austria', 'PL': 'Poland', 'PT': 'Portugal', 'RO': 'Romania', 'SI': 'Slovenia', 'SK': 'Slovakia', 'FI': 'Finland', 'SE': 'Sweden', 'UK': 'United Kingdom', 'TR': 'Türkiye', 'US': 'United States', 'JP': 'Japan'}}, 'time': {'text': 'Time', 'values': {}}}, 'url': 'https://ec.europa.eu/eurostat/databrowser/view/ei_mfir_m/default/table'}
# {'text': '3-month-interest rate', 'start_date': array([2023], dtype=int64), 'end_date': array([2023], dtype=int64), 'variables': {'freq': {'text': 'Time frequency', 'values': {'M': 'Monthly'}}, 'int_rt': {'text': 'Interest rate', 'values': {'IRT_M3': '3-month rate'}}, 'geo': {'text': 'Geopolitical entity (reporting)', 'values': {'EA': 'Euro area (EA11-1999, EA12-2001, EA13-2007, EA15-2008, EA16-2009, EA17-2011, EA18-2014, EA19-2015, EA20-2023)', 'BG': 'Bulgaria', 'CZ': 'Czechia', 'DK': 'Denmark', 'HR': 'Croatia', 'HU': 'Hungary', 'PL': 'Poland', 'RO': 'Romania', 'SE': 'Sweden', 'UK': 'United Kingdom', 'TR': 'Türkiye', 'US': 'United States', 'JP': 'Japan'}}, 'time': {'text': 'Time', 'values': {}}}, 'url': 'https://ec.europa.eu/eurostat/databrowser/view/teimf040/default/table'}
# {'text': 'Day-to-day money market interest rates', 'start_date': array([2023], dtype=int64), 'end_date': array([2023], dtype=int64), 'variables': {'freq': {'text': 'Time frequency', 'values': {'M': 'Monthly'}}, 'int_rt': {'text': 'Interest rate', 'values': {'IRT_DTD': 'Day-to-day rate'}}, 'geo': {'text': 'Geopolitical entity (reporting)', 'values': {'EA': 'Euro area (EA11-1999, EA12-2001, EA13-2007, EA15-2008, EA16-2009, EA17-2011, EA18-2014, EA19-2015, EA20-2023)', 'BG': 'Bulgaria', 'CZ': 'Czechia', 'DK': 'Denmark', 'HR': 'Croatia', 'HU': 'Hungary', 'PL': 'Poland', 'RO': 'Romania', 'SE': 'Sweden', 'UK': 'United Kingdom', 'TR': 'Türkiye', 'US': 'United States', 'JP': 'Japan'}}, 'time': {'text': 'Time', 'values': {}}}, 'url': 'https://ec.europa.eu/eurostat/databrowser/view/teimf100/default/table'}
# {'text': 'Tax rate', 'start_date': array([2022], dtype=int64), 'end_date': array([2000], dtype=int64), 'variables': {'freq': {'text': 'Time frequency', 'values': {'A': 'Annual'}}, 'ecase': {'text': 'Earnings case', 'values': {'P1_NCH_AW50': 'Single person without children earning 50% of the average earning', 'P1_NCH_AW67': 'Single person without children earning 67% of the average earning', 'P1_NCH_AW80': 'Single person without children earning 80% of the average earning', 'P1_NCH_AW100': 'Single person without children earning 100% of the average earning', 'P1_NCH_AW125': 'Single person without children earning 125% of the average earning', 'P1_NCH_AW167': 'Single person without children earning 167% of the average earning', 'P1_CH2_AW67': 'Single person with two children earning 67% of the average earning', 'CPL_CH2_AW100': 'One-earner couple with two children earning 100% of the average earning', 'CPL_CH2_AW100_33': 'Two-earner couple with two children, one earning 100% and the other 33% of the average earning', 'CPL_CH2_AW100_67': 'Two-earner couple with two children, one earning 100% and the other 67% of the average earning', 'CPL_CH2_AW100_100': 'Two-earner couple with two children, both earning 100% of the average earning', 'CPL_NCH_AW100_33': 'Two-earner couple without children, one earning 100% and the other 33% of the average earning', 'CPL_NCH_AW100_100': 'Two-earner couple without children, both earning 100% of the average earning'}}, 'geo': {'text': 'Geopolitical entity (reporting)', 'values': {'EU27_2020': 'European Union - 27 countries (from 2020)', 'EU28': 'European Union - 28 countries (2013-2020)', 'EU15': 'European Union - 15 countries (1995-2004)', 'EA20': 'Euro area – 20 countries (from 2023)', 'EA19': 'Euro area - 19 countries  (2015-2022)', 'BE': 'Belgium', 'BG': 'Bulgaria', 'CZ': 'Czechia', 'DK': 'Denmark', 'DE': 'Germany', 'EE': 'Estonia', 'IE': 'Ireland', 'EL': 'Greece', 'ES': 'Spain', 'FR': 'France', 'HR': 'Croatia', 'IT': 'Italy', 'CY': 'Cyprus', 'LV': 'Latvia', 'LT': 'Lithuania', 'LU': 'Luxembourg', 'HU': 'Hungary', 'MT': 'Malta', 'NL': 'Netherlands', 'AT': 'Austria', 'PL': 'Poland', 'PT': 'Portugal', 'RO': 'Romania', 'SI': 'Slovenia', 'SK': 'Slovakia', 'FI': 'Finland', 'SE': 'Sweden', 'IS': 'Iceland', 'NO': 'Norway', 'CH': 'Switzerland', 'UK': 'United Kingdom', 'TR': 'Türkiye', 'US': 'United States', 'JP': 'Japan'}}, 'time': {'text': 'Time', 'values': {}}}, 'url': 'https://ec.europa.eu/eurostat/databrowser/view/earn_nt_taxrate/default/table'}
# {'text': 'Money market interest rates - annual data', 'start_date': array([2023], dtype=int64), 'end_date': array([1970], dtype=int64), 'variables': {'freq': {'text': 'Time frequency', 'values': {'A': 'Annual'}}, 'int_rt': {'text': 'Interest rate', 'values': {'IRT_DTD': 'Day-to-day rate', 'IRT_M1': '1-month rate', 'IRT_M3': '3-month rate', 'IRT_M6': '6-month rate', 'IRT_M12': '12-month rate'}}, 'geo': {'text': 'Geopolitical entity (reporting)', 'values': {'EA': 'Euro area (EA11-1999, EA12-2001, EA13-2007, EA15-2008, EA16-2009, EA17-2011, EA18-2014, EA19-2015, EA20-2023)', 'BG': 'Bulgaria', 'CZ': 'Czechia', 'DK': 'Denmark', 'HR': 'Croatia', 'LV': 'Latvia', 'LT': 'Lithuania', 'HU': 'Hungary', 'PL': 'Poland', 'RO': 'Romania', 'SE': 'Sweden', 'UK': 'United Kingdom', 'TR': 'Türkiye', 'US': 'United States', 'JP': 'Japan'}}, 'time': {'text': 'Time', 'values': {}}}, 'url': 'https://ec.europa.eu/eurostat/databrowser/view/irt_st_a/default/table'}
# {'text': 'Money market interest rates - monthly data', 'start_date': array([2023], dtype=int64), 'end_date': array([1970], dtype=int64), 'variables': {'freq': {'text': 'Time frequency', 'values': {'M': 'Monthly'}}, 'int_rt': {'text': 'Interest rate', 'values': {'IRT_DTD': 'Day-to-day rate', 'IRT_M1': '1-month rate', 'IRT_M3': '3-month rate', 'IRT_M6': '6-month rate', 'IRT_M12': '12-month rate'}}, 'geo': {'text': 'Geopolitical entity (reporting)', 'values': {'EA': 'Euro area (EA11-1999, EA12-2001, EA13-2007, EA15-2008, EA16-2009, EA17-2011, EA18-2014, EA19-2015, EA20-2023)', 'BG': 'Bulgaria', 'CZ': 'Czechia', 'DK': 'Denmark', 'HR': 'Croatia', 'LV': 'Latvia', 'LT': 'Lithuania', 'HU': 'Hungary', 'PL': 'Poland', 'RO': 'Romania', 'SE': 'Sweden', 'UK': 'United Kingdom', 'MK': 'North Macedonia', 'TR': 'Türkiye', 'US': 'United States', 'JP': 'Japan'}}, 'time': {'text': 'Time', 'values': {}}}, 'url': 'https://ec.europa.eu/eurostat/databrowser/view/irt_st_m/default/table'}
# {'text': 'Money market interest rates - quarterly data', 'start_date': array([2023], dtype=int64), 'end_date': array([1970], dtype=int64), 'variables': {'freq': {'text': 'Time frequency', 'values': {'Q': 'Quarterly'}}, 'int_rt': {'text': 'Interest rate', 'values': {'IRT_DTD': 'Day-to-day rate', 'IRT_M1': '1-month rate', 'IRT_M3': '3-month rate', 'IRT_M6': '6-month rate', 'IRT_M12': '12-month rate'}}, 'geo': {'text': 'Geopolitical entity (reporting)', 'values': {'EA': 'Euro area (EA11-1999, EA12-2001, EA13-2007, EA15-2008, EA16-2009, EA17-2011, EA18-2014, EA19-2015, EA20-2023)', 'BG': 'Bulgaria', 'CZ': 'Czechia', 'DK': 'Denmark', 'HR': 'Croatia', 'LV': 'Latvia', 'LT': 'Lithuania', 'HU': 'Hungary', 'PL': 'Poland', 'RO': 'Romania', 'SE': 'Sweden', 'UK': 'United Kingdom', 'TR': 'Türkiye', 'US': 'United States', 'JP': 'Japan'}}, 'time': {'text': 'Time', 'values': {}}}, 'url': 'https://ec.europa.eu/eurostat/databrowser/view/irt_st_q/default/table'}
# {'text': 'Exchange rates', 'start_date': array([2019], dtype=int64), 'end_date': array([2005], dtype=int64), 'variables': {'freq': {'text': 'Time frequency', 'values': {'A': 'Annual'}}, 'currency': {'text': 'Currency', 'values': {'EUR': 'Euro'}}, 'geo': {'text': 'Geopolitical entity (reporting)', 'values': {'DZ': 'Algeria', 'EG': 'Egypt', 'LY': 'Libya', 'MA': 'Morocco', 'TN': 'Tunisia', 'IL': 'Israel', 'JO': 'Jordan', 'LB': 'Lebanon'}}, 'time': {'text': 'Time', 'values': {}}}, 'url': 'https://ec.europa.eu/eurostat/databrowser/view/med_ec9/default/table'}
# {'text': 'Loan and deposit one year interest rate', 'start_date': array([2022], dtype=int64), 'end_date': array([2005], dtype=int64), 'variables': {'freq': {'text': 'Time frequency', 'values': {'A': 'Annual'}}, 'unit': {'text': 'Unit of measure', 'values': {'RT': 'Rate'}}, 'stk_flow': {'text': 'Stock or flow', 'values': {'LOAN': 'Loan', 'DPT': 'Deposit'}}, 'geo': {'text': 'Geopolitical entity (reporting)', 'values': {'MD': 'Moldova', 'UA': 'Ukraine', 'GE': 'Georgia', 'BY': 'Belarus', 'AM': 'Armenia', 'AZ': 'Azerbaijan'}}, 'time': {'text': 'Time', 'values': {}}}, 'url': 'https://ec.europa.eu/eurostat/databrowser/view/enpe_irt_ld/default/table'}
